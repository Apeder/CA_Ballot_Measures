# %%
from tabula.io import read_pdf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Make plots wider for longer timeseries
plt.rcParams["figure.figsize"] = (20,10)

# %%
#Source: CA Secretary of State: https://elections.cdn.sos.ca.gov//ballot-measures/pdf/initiative-totals-summary-year.pdf
#Read in .pdf from local directory - also possible to use URL
df = read_pdf("initiative-totals-summary-year.pdf", output_format='dataframe', pages='1-3', lattice=True)

# %%
#Rename columns and check resulting dataframe
df[0].columns = ['Year', 'Titled', 'Qualified','Approved','Rejected',
                                             'Failed','Withdrawn']
df[0]
# Out:
#                                                   Year  Titled  \
# 0                                         Summary Year  Titled
# 1                                                 1912       5
# 2                                                 1913       5
# 3                                                 1914      21
# 4                                                 1915       2
# ..                                                 ...     ...
# 105  4 One initiative that qualified for the March ...     NaN
# 106  5 One initiative that qualified for the Novemb...     NaN
# 107  6 Two initiatives are eligible for the Novembe...     NaN
# 108  7 Two initiatives are eligible for the Novembe...     NaN
# 109  8 Of the 138 approved initiatives, 137 were ap...     NaN
#
#                   Qualified  Approved  Rejected  Failed  Withdrawn
# 0    Qualified/\rEligible 1  Approved  Rejected  Failed  Withdrawn
# 1                         4         1         3       1          0
# 2                         4         2         2       1          0
# 3                        12         3         9       9          0
# 4                         2         0         2       0          0
# ..                      ...       ...       ...     ...        ...
# 105                     NaN       NaN       NaN     NaN        NaN
# 106                     NaN       NaN       NaN     NaN        NaN
# 107                     NaN       NaN       NaN     NaN        NaN
# 108                     NaN       NaN       NaN     NaN        NaN
# 109                     NaN       NaN       NaN     NaN        NaN
#
# [110 rows x 7 columns]

# %%
#Tabula outputs a list of dfs found as tables in the .pdf, and our data is in df[0]. However, each page's 
#heading and all footnotes have been added as records.
df[0].tail(10)
# Out:
#                                                   Year Titled Qualified  \
# 100                                               2023      5         0
# 101                                            TOTAL 8  2,117       400
# 102  1 Initiatives become eligible for the ballot o...    NaN       NaN
# 103  2 One indirect initiative was adopted by the L...    NaN       NaN
# 104  3 Two initiatives that qualified for the 1984 ...    NaN       NaN
# 105  4 One initiative that qualified for the March ...    NaN       NaN
# 106  5 One initiative that qualified for the Novemb...    NaN       NaN
# 107  6 Two initiatives are eligible for the Novembe...    NaN       NaN
# 108  7 Two initiatives are eligible for the Novembe...    NaN       NaN
# 109  8 Of the 138 approved initiatives, 137 were ap...    NaN       NaN
#
#     Approved Rejected Failed Withdrawn
# 100        0        0      0         0
# 101      138      254  1,575       137
# 102      NaN      NaN    NaN       NaN
# 103      NaN      NaN    NaN       NaN
# 104      NaN      NaN    NaN       NaN
# 105      NaN      NaN    NaN       NaN
# 106      NaN      NaN    NaN       NaN
# 107      NaN      NaN    NaN       NaN
# 108      NaN      NaN    NaN       NaN
# 109      NaN      NaN    NaN       NaN

# %%
df[0].loc[df[0]['Titled']=='Titled']
# Out:
#             Year  Titled               Qualified  Approved  Rejected  Failed  \
# 0   Summary Year  Titled  Qualified/\rEligible 1  Approved  Rejected  Failed
# 47  Summary Year  Titled  Qualified/\rEligible 1  Approved  Rejected  Failed
# 96  Summary Year  Titled  Qualified/\rEligible 1  Approved  Rejected  Failed
#
#     Withdrawn
# 0   Withdrawn
# 47  Withdrawn
# 96  Withdrawn

# %%
#We delete both
Ballot_Results = df[0].drop(list(range(101,110))+[0,47,96])

#Footnotes in the orignal year column confuse a conversion to numeric data type, so we strip 
#any more than 4 characters in the year column
Ballot_Results['Year'] = Ballot_Results['Year'].str[:4]

#Check resulting DataFrame
Ballot_Results
# Out:
#      Year Titled Qualified Approved Rejected Failed Withdrawn
# 1    1912      5         4        1        3      1         0
# 2    1913      5         4        2        2      1         0
# 3    1914     21        12        3        9      9         0
# 4    1915      2         2        0        2      0         0
# 5    1916      3         2        1        1      1         0
# ..    ...    ...       ...      ...      ...    ...       ...
# 95   2019     20         5        2        3     13         2
# 97   2020     11         2        1        1      8         1
# 98   2021     35         4        0        2     29         2
# 99   2022      9         4        1        1      4         1
# 100  2023      5         0        0        0      0         0
#
# [98 rows x 7 columns]

# %%
#Convert all columns to int data type
cols = Ballot_Results.columns 
Ballot_Results[cols]= Ballot_Results[cols].astype(int)

# %%
Ballot_Results.describe()
# Out:
#               Year      Titled  Qualified   Approved   Rejected     Failed  \
# count    98.000000   98.000000  98.000000  98.000000  98.000000  98.000000
# mean   1971.040816   21.591837   4.071429   1.408163   2.581633  16.071429
# std      32.967312   20.962331   3.140195   1.449043   2.134273  17.766672
# min    1912.000000    1.000000   0.000000   0.000000   0.000000   0.000000
# 25%    1942.500000    5.250000   1.250000   0.000000   1.000000   2.000000
# 50%    1974.500000   15.000000   3.500000   1.000000   2.000000   9.000000
# 75%    1998.750000   34.750000   6.000000   2.000000   4.000000  25.750000
# max    2023.000000  109.000000  12.000000   6.000000   9.000000  97.000000
#
#        Withdrawn
# count  98.000000
# mean    1.397959
# std     2.358314
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     2.000000
# max    11.000000

# %%
Ballot_Results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 1 to 100
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       98 non-null     int64
#  1   Titled     98 non-null     int64
#  2   Qualified  98 non-null     int64
#  3   Approved   98 non-null     int64
#  4   Rejected   98 non-null     int64
#  5   Failed     98 non-null     int64
#  6   Withdrawn  98 non-null     int64
# dtypes: int64(7)
# memory usage: 6.1 KB

# %%
#Looks like modern era (after 1970 or so) has more cyclical activity
Ballot_Results.plot(x='Year', y='Approved')
# Out:
# <Axes: xlabel='Year'>

# %%
#While many more potential ballot measures have been title, most seem to have failed before qualifiying to 
#be on the ballot. 2000-2020 was an especially popular period for titling ballot measures
Ballot_Results.plot(x='Year')
# Out:
# <Axes: xlabel='Year'>

# %%
#Historically, the number ballot measures that are qualified and appear on the ballot is more stable, with a 
#noticeable lull in between 1950 and 1970 or so.
Ballot_Results.plot(x='Year',y=['Qualified','Approved','Rejected'])
# Out:
# <Axes: xlabel='Year'>

# %%
Modern_Results = Ballot_Results.loc[Ballot_Results['Year'] > 1972]
Modern_Results.plot(x='Year',y=['Qualified','Approved','Rejected','Withdrawn'])
# Out:
# <Axes: xlabel='Year'>

# %%
Modern_Results.plot(x='Year',y=['Qualified','Approved','Rejected'])
# Out:
# <Axes: xlabel='Year'>

# %%
fig1,axes = plt.subplots(2,1, sharex=True)

plt.subplots_adjust(wspace=0,hspace=0)
plt.grid(which='major', axis='x')

axes[0].plot(Ballot_Results['Year'],Ballot_Results[['Titled','Failed','Withdrawn']])
axes[0].legend(['Titled','Failed','Withdrawn'])
axes[0].grid(which='major', axis='x')
axes[0].set_title('CA Ballot Measure Success 1912-2023')

axes[1].plot(Ballot_Results['Year'],Ballot_Results[['Qualified','Approved','Rejected']])
axes[1].legend(['Qualified','Approved','Rejected'])
axes[1].set_xticks(list(range(1912,2023,5)))
axes[1].set_xlim(1912,2023)
axes[1].set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
fig2,axes2 = plt.subplots(2,1, sharex=True)

plt.subplots_adjust(wspace=0,hspace=.05)
plt.grid(which='major', axis='x')

axes2[0].bar(Ballot_Results['Year'],Ballot_Results['Titled'])
axes2[0].bar(Ballot_Results['Year'],Ballot_Results['Failed'],bottom=Ballot_Results['Titled'])
axes2[0].bar(Ballot_Results['Year'],Ballot_Results['Withdrawn'],bottom=np.add(Ballot_Results['Titled'],
                                                                             Ballot_Results['Failed']))
axes2[0].legend(['Titled','Failed','Withdrawn'])
axes2[0].grid(which='major', axis='x')
axes2[0].set_title('CA Ballot Measure Success 1912-2023')

axes2[1].bar(Ballot_Results['Year'],Ballot_Results['Qualified'])
axes2[1].bar(Ballot_Results['Year'],Ballot_Results['Approved'], bottom=Ballot_Results['Qualified'])
axes2[1].bar(Ballot_Results['Year'],Ballot_Results['Rejected'],bottom=np.add(Ballot_Results['Qualified'],
                                                                            Ballot_Results['Approved']))

axes2[1].legend(['Qualified','Approved','Rejected'])
axes2[1].set_xticks(list(range(1912,2023,5)))
axes2[1].set_xlim(1912,2023)
axes2[1].set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
Modern_Results.plot(x='Year',y=['Qualified','Rejected','Approved'],kind='bar',stacked=True, 
                    title='CA Ballot Measure Success 1972-2023')
# Out:
# <Axes: title={'center': 'CA Ballot Measure Success 1972-2023'}, xlabel='Year'>

# %%
#Read in larger dataset for next phase - need to collect money spent for and against, polling and vote results.
#Contributions will need to be adjusted for inflation. Also not clear if there are major events to explain
#some years with many more or fewer things on the ballot.
df3 = read_pdf("https://elections.cdn.sos.ca.gov/ballot-measures/pdf/initiatives-by-title-and-summary-year.pdf", 
               output_format='dataframe', pages='all',lattice=True)

# %%
df3[0].drop(['Unnamed: 2'],axis=1,inplace=True)
df3[0].drop([3662,3664,3666,3668,3670],inplace=True)
df3[0].dropna(how='all',inplace=True)
df3[0].columns = ['Year','InitNumber', 'Title', 'Qualified/Failed','PropNum','Appoved/Rejected','ElectionYear']
df3[0].drop(df3[0].loc[df3[0]['Year']=='YEAR'].index, inplace=True)

df3[0]
# Out:
#       Year InitNumber                                              Title  \
# 4     1912        NaN                         Abolition of Death Penalty
# 5     1912        NaN  Formation of Consolidated City and County Gove...
# 6     1912        NaN  Prohibit Bookmaking and Appointment of Racing ...
# 7     1912        NaN       Relating to Taxation by Counties-Cities (CA)
# 8     1912        NaN                     Abolition of the Poll Tax (CA)
# ...    ...        ...                                                ...
# 3657  2023       1941                                            Pending
# 3658  2023       1942                                            Pending
# 3659  2023       1943                                            Pending
# 3660  2023       1944                                            Pending
# 3661  2023       1945                                            Pending
#
#      Qualified/Failed PropNum Appoved/Rejected ElectionYear
# 4                   F     NaN              NaN          NaN
# 5                   Q     NaN                R         1912
# 6                   Q     NaN                R         1912
# 7                   Q     NaN                R         1912
# 8                   Q      10                A         1914
# ...               ...     ...              ...          ...
# 3657              NaN     NaN              NaN          NaN
# 3658              NaN     NaN              NaN          NaN
# 3659              NaN     NaN              NaN          NaN
# 3660              NaN     NaN              NaN          NaN
# 3661              NaN     NaN              NaN          NaN
#
# [2628 rows x 7 columns]

# %%
df3[0].describe()
# Out:
#         Year InitNumber Title Qualified/Failed PropNum Appoved/Rejected  \
# count   2626       1852  2117             1332     391              399
# unique   104       1851  1033              107      97               29
# top     2005        394     F                F       R                R
# freq     109          2   696              879      93              161
#
#        ElectionYear
# count           242
# unique           56
# top            1914
# freq             17

# %%
df3[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2628 entries, 4 to 3661
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              2626 non-null   object
#  1   InitNumber        1852 non-null   object
#  2   Title             2117 non-null   object
#  3   Qualified/Failed  1332 non-null   object
#  4   PropNum           391 non-null    object
#  5   Appoved/Rejected  399 non-null    object
#  6   ElectionYear      242 non-null    object
# dtypes: object(7)
# memory usage: 164.2+ KB

# %%
Full_Ballot_Measure_Data = df3[0]
Full_Ballot_Measure_Data.to_csv('Full_Ballot_Measure_Data.csv')
